# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n1 = np.array([1,2,3,4,5])
n2 = np.array([1,2,3,4,5])

# %%
# labels
plt.plot(n1,n2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
