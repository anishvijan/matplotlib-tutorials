# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,2,3,4])
y = np.array([1,2,3,4])

# %%
# bar plot
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
bar = plt.bar(x,y)
bar[0].set_hatch('/')
bar[1].set_hatch('.')
bar[2].set_hatch('*')
bar[3].set_hatch('o')
