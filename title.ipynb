# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# title
plt.plot([1,2,3,4],[1,2,3,4])
plt.title('Basic Title')
# Out:
# Text(0.5, 1.0, 'Basic Title')

# %%
# changing font of title
plt.plot([1,2,3,4],[1,2,3,4],'o-')
plt.title('Basic Title', fontdict={'family': 'serif'})
# Out:
# Text(0.5, 1.0, 'Basic Title')
