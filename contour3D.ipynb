# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np

# %%
# contour 3D
x = np.array([1,2,3,4])
y = np.array([1,2,3,4])
x,y = np.meshgrid(x,y)
z = x**2+y**2
ax = plt.axes(projection = '3d')
ax.contour3D(x,y,z)
